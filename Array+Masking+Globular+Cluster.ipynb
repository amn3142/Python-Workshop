# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f_stars = np.loadtxt('/Users/andrewgraus/Work/python_workshop/star_dataset.txt')

print f_stars.shape

print f_stars[0]

x = f_stars[:,0]
y = f_stars[:,1]
V = f_stars[:,2]
B = f_stars[:,3]

x_c, y_c = 1000.0,1100.0

distance = np.sqrt((x-x_c)**2.0+(y-y_c)**2.0)
distance_mask = (distance<1000.0)

cluster_mask = ()

plt.figure(1,(10,10))
plt.scatter(x,y,s=1)
plt.scatter(x[distance_mask],y[distance_mask],color='m',s=1)

plt.figure(2,(10,10))
plt.scatter(B-V,V,s=1)
plt.scatter(B[distance_mask]-V[distance_mask],V[distance_mask],s=1,color='m')
plt.ylim([26.0,12.0])

plt.show()
# Out:
# (76916, 4)
# [ 1176.271        554.81          11.25500011    12.15499973]
